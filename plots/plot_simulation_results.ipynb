# %%
import pandas as pd
import seaborn as sns

# %%
sim_df = pd.read_csv('../runs/h_13129_0.5_0.03/sim_data.csv', index_col='timeslot')

# %%
sim_df.head()
# Out:
#           carbon_footprint  brown_energy  green_energy  acceptance_ratio  \
# timeslot
# 0                    0.000         0.000         0.000             100.0
# 1                   39.081        32.308        29.385             100.0
# 2                   52.053        41.957        26.764             100.0
# 3                   67.134        56.194        25.613             100.0
# 4                  113.349        95.657        23.904             100.0
#
#           migration_count  ps_min  ps_5th    ps_mean  ps_95th  ps_max
# timeslot
# 0                       0    13.0    13.0  16.000000    20.00    20.0
# 1                       0    14.0    14.0  15.875000    18.65    19.0
# 2                       0    13.0    13.7  16.500000    19.65    20.0
# 3                       0    15.0    15.0  17.733333    20.00    20.0
# 4                       0    14.0    14.0  16.636364    19.50    20.0

# %%
sns.pairplot(sim_df[['acceptance_ratio', 'brown_energy', 'green_energy']],diag_kind='kde')
